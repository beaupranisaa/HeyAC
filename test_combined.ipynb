# %%
from hey_ac import HeyAC
import yaml

# %%
h = HeyAC(grammar_path = 'grammars/grammar_combined.txt')

# %%
texts = [
    'it is hot in here',
    'the speed of the fan is too low',
    'fan speed is low',
    'temperature is high',
    'humidity feels too high',
    'The room is very damp',
    'It is burning',
    'it is so cold',
    'the fan is not quite fast',
    'i feel very hot',
    'i am freezing',
    'it is freezing',
    'it is dry in here',
    'the dog feels cold',
    'the ac is very weak',
    'the volume of air is so low',
    'the ac is not running',
    'the flap is not moving',
    'the swing is swinging',
    'The air from the ac is burning',
    'the wind is icy',
    'I am feeling very cold',
    'The AC is running hot',
    "it is not cold enough in the room",
    "i am feeling too hot in here",
    'turn up the heat',
    'turn the AC off',
    'turn on the fan mode',
    'turn off the fan',
    'turn down the temperature',
    'turn down the fan',
    'swing up the air',
    'swing the AC',
    'stop the swing',
    'reduce the temperature',
    'raise the temperature',
    'pause the swing',
    'increase the humidity',
    'increase the fan speed',
    'activate fan mode',
    'increase the temperature',
    'lower the fan speed',
    'lower the air',
    'dry the room',
    'decrease the humidity',
    'turn up the temperature by 3 degrees',
    'turn on the air-conditioner', #for me
    'turn on the AC to 28 degrees',
    'turn the AC on to 25 degrees',
    'turn on the air-conditioner from 7 am to 4 p.m.',
    "turn on the air at 4 o'clock",
    "increase the temperature by 3 degrees",
    'decrease the fan speed',
    'cool down the room by 2 degrees',
    "set the humidity to 23 %",
    "set to fan mode",
    "set the mode to cooling mode",
    'turn on the air conditioner'
]

# %%
for text in texts:
    print("="*50)
    print(text)
    print()
    h.classify(text)
# Out:
# ==================================================
# it is hot in here
#
# [WARNING] More than a single parse detected
# [INDIRECT COMMAND]
# [VALUE] HOT
# [NEG] False
# [OBJ] ENVIRONMENT
# [KEY] TEMP_DOWN
#
# [RESPONSE] Decreasing the temperature.
# ==================================================
# the speed of the fan is too low
#
# [INDIRECT COMMAND]
# [VALUE] LOW
# [NEG] False
# [PROP] VOLUME
# [OBJ] FAN
# [KEY] FAN_UP
#
# [RESPONSE] Increasing the air volume.
# ==================================================
# fan speed is low
#
# [INDIRECT COMMAND]
# [VALUE] LOW
# [NEG] False
# [PROP] VOLUME
# [OBJ] FAN
# [KEY] FAN_UP
#
# [RESPONSE] Increasing the air volume.
# ==================================================
# temperature is high
#
# [INDIRECT COMMAND]
# [VALUE] HIGH
# [NEG] False
# [PROP] TEMPERATURE
# [KEY] TEMP_DOWN
#
# [RESPONSE] Decreasing the temperature.
# ==================================================
# humidity feels too high
#
# [INDIRECT COMMAND]
# [VALUE] HIGH
# [NEG] False
# [PROP] HUMIDITY
# [KEY] HUMIDITY_DOWN
#
# [RESPONSE] Drying the room.
# ==================================================
# The room is very damp
#
# [INDIRECT COMMAND]
# [VALUE] HUMID
# [NEG] False
# [OBJ] ENVIRONMENT
# [KEY] HUMIDITY_DOWN
#
# [RESPONSE] Drying the room.
# ==================================================
# It is burning
#
# [WARNING] More than a single parse detected
# [INDIRECT COMMAND]
# [VALUE] HOT
# [NEG] False
# [OBJ] ENVIRONMENT
# [KEY] TEMP_DOWN
#
# [RESPONSE] Decreasing the temperature.
# ==================================================
# it is so cold
#
# [WARNING] More than a single parse detected
# [INDIRECT COMMAND]
# [VALUE] COLD
# [NEG] False
# [OBJ] ENVIRONMENT
# [KEY] TEMP_UP
#
# [RESPONSE] Increasing the temperature.
# ==================================================
# the fan is not quite fast
#
# [INDIRECT COMMAND]
# [VALUE] FAST
# [NEG] True
# [OBJ] FAN
# [KEY] FAN_UP
#
# [RESPONSE] Increasing the air volume.
# ==================================================
# i feel very hot
#
# [INDIRECT COMMAND]
# [VALUE] HOT
# [NEG] False
# [OBJ] USER
# [KEY] TEMP_DOWN
#
# [RESPONSE] Decreasing the temperature.
# ==================================================
# i am freezing
#
# [INDIRECT COMMAND]
# [VALUE] COLD
# [NEG] False
# [OBJ] USER
# [KEY] TEMP_UP
#
# [RESPONSE] Increasing the temperature.
# ==================================================
# it is freezing
#
# [WARNING] More than a single parse detected
# [INDIRECT COMMAND]
# [VALUE] COLD
# [NEG] False
# [OBJ] ENVIRONMENT
# [KEY] TEMP_UP
#
# [RESPONSE] Increasing the temperature.
# ==================================================
# it is dry in here
#
# [WARNING] More than a single parse detected
# [INDIRECT COMMAND]
# [VALUE] DRY
# [NEG] False
# [OBJ] ENVIRONMENT
# [KEY] HUMIDITY_UP
#
# [RESPONSE] Humidifying the room.
# ==================================================
# the dog feels cold
#
# [INDIRECT COMMAND]
# [VALUE] COLD
# [NEG] False
# [OBJ] USER
# [KEY] TEMP_UP
#
# [RESPONSE] Increasing the temperature.
# ==================================================
# the ac is very weak
#
# [INDIRECT COMMAND]
# [VALUE] WEAK
# [NEG] False
# [OBJ] AC
# [KEY] FAN_UP
#
# [RESPONSE] Increasing the air volume.
# ==================================================
# the volume of air is so low
#
# [WARNING] More than a single parse detected
# [INDIRECT COMMAND]
# [VALUE] LOW
# [NEG] False
# [PROP] VOLUME
# [OBJ] ENVIRONMENT
# [KEY] FAN_UP
#
# [RESPONSE] Increasing the air volume.
# ==================================================
# the ac is not running
#
# [INDIRECT COMMAND]
# [VALUE] RUNNING
# [NEG] True
# [OBJ] AC
# [KEY] TURN_ON
#
# [RESPONSE] Started AC.
# ==================================================
# the flap is not moving
#
# [INDIRECT COMMAND]
# [VALUE] MOVING
# [NEG] True
# [OBJ] SWING
# [KEY] SWING_START
#
# [RESPONSE] Started swinging.
# ==================================================
# the swing is swinging
#
# [INDIRECT COMMAND]
# [VALUE] SWINGING
# [NEG] False
# [OBJ] SWING
# [KEY] SWING_STOP
#
# [RESPONSE] Stopped swinging.
# ==================================================
# The air from the ac is burning
#
# [INDIRECT COMMAND]
# [VALUE] HOT
# [NEG] False
# [PROP] BREEZE
# [OBJ] AC
# [KEY] TEMP_DOWN
#
# [RESPONSE] Decreasing the temperature.
# ==================================================
# the wind is icy
#
# [INDIRECT COMMAND]
# [VALUE] COLD
# [NEG] False
# [PROP] BREEZE
# [KEY] TEMP_UP
#
# [RESPONSE] Increasing the temperature.
# ==================================================
# I am feeling very cold
#
# [INDIRECT COMMAND]
# [VALUE] COLD
# [NEG] False
# [OBJ] USER
# [KEY] TEMP_UP
#
# [RESPONSE] Increasing the temperature.
# ==================================================
# The AC is running hot
#
# [INDIRECT COMMAND]
# [VALUE] HOT
# [NEG] False
# [OBJ] AC
# [KEY] TEMP_DOWN
#
# [RESPONSE] Decreasing the temperature.
# ==================================================
# it is not cold enough in the room
#
# [WARNING] More than a single parse detected
# [INDIRECT COMMAND]
# [VALUE] COLD
# [NEG] True
# [OBJ] ENVIRONMENT
# [KEY] TEMP_DOWN
#
# [RESPONSE] Decreasing the temperature.
# ==================================================
# i am feeling too hot in here
#
# [INDIRECT COMMAND]
# [VALUE] HOT
# [NEG] False
# [OBJ] USER
# [KEY] TEMP_DOWN
#
# [RESPONSE] Decreasing the temperature.
# ==================================================
# turn up the heat
#
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [PROP] TEMPERATURE
# [DIR] UP
# [KEY] TEMP_UP
#
# [RESPONSE] Increasing the temperature.
# ==================================================
# turn the AC off
#
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [OBJ] AC
# [DIR] OFF
# [KEY] TURN_OFF
#
# [RESPONSE] Stopped AC.
# ==================================================
# turn on the fan mode
#
# [WARNING] More than a single parse detected
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [PROP] MODE
# [OBJ] FAN
# [DIR] ON
# [KEY] TURN_ON
#
# [RESPONSE] Started AC.
# ==================================================
# turn off the fan
#
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [OBJ] FAN
# [DIR] OFF
# [KEY] TURN_OFF
#
# [RESPONSE] Stopped AC.
# ==================================================
# turn down the temperature
#
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [PROP] TEMPERATURE
# [DIR] DOWN
# [KEY] TEMP_DOWN
#
# [RESPONSE] Decreasing the temperature.
# ==================================================
# turn down the fan
#
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [OBJ] FAN
# [DIR] DOWN
# [KEY] FAN_DOWN
#
# [RESPONSE] Decreasing the air volume.
# ==================================================
# swing up the air
#
# [WARNING] More than a single parse detected
# [DIRECT COMMAND]
# [ACT] SWING_ACT
# [PROP] BREEZE
# [DIR] UP
# [KEY] SWING_UP
#
# [RESPONSE] Swinging upwards.
# ==================================================
# swing the AC
#
# [DIRECT COMMAND]
# [ACT] SWING_ACT
# [OBJ] AC
# [KEY] SWING_START
#
# [RESPONSE] Started swinging.
# ==================================================
# stop the swing
#
# [DIRECT COMMAND]
# [ACT] STOP
# [OBJ] SWING
# [KEY] SWING_STOP
#
# [RESPONSE] Stopped swinging.
# ==================================================
# reduce the temperature
#
# [DIRECT COMMAND]
# [ACT] DECREASE
# [PROP] TEMPERATURE
# [KEY] TEMP_DOWN
#
# [RESPONSE] Decreasing the temperature.
# ==================================================
# raise the temperature
#
# [DIRECT COMMAND]
# [ACT] INCREASE
# [PROP] TEMPERATURE
# [KEY] TEMP_UP
#
# [RESPONSE] Increasing the temperature.
# ==================================================
# pause the swing
#
# [DIRECT COMMAND]
# [ACT] STOP
# [OBJ] SWING
# [KEY] SWING_STOP
#
# [RESPONSE] Stopped swinging.
# ==================================================
# increase the humidity
#
# [DIRECT COMMAND]
# [ACT] INCREASE
# [PROP] HUMIDITY
# [KEY] HUMIDITY_UP
#
# [RESPONSE] Humidifying the room.
# ==================================================
# increase the fan speed
#
# [DIRECT COMMAND]
# [ACT] INCREASE
# [PROP] VOLUME
# [OBJ] FAN
# [KEY] FAN_UP
#
# [RESPONSE] Increasing the air volume.
# ==================================================
# activate fan mode
#
# [WARNING] More than a single parse detected
# [DIRECT COMMAND]
# [ACT] ACTIVATE
# [PROP] MODE
# [OBJ] FAN
# [KEY] TURN_ON
#
# [RESPONSE] Started AC.
# ==================================================
# increase the temperature
#
# [DIRECT COMMAND]
# [ACT] INCREASE
# [PROP] TEMPERATURE
# [KEY] TEMP_UP
#
# [RESPONSE] Increasing the temperature.
# ==================================================
# lower the fan speed
#
# [DIRECT COMMAND]
# [ACT] DECREASE
# [PROP] VOLUME
# [OBJ] FAN
# [KEY] FAN_DOWN
#
# [RESPONSE] Decreasing the air volume.
# ==================================================
# lower the air
#
# [WARNING] More than a single parse detected
# [DIRECT COMMAND]
# [ACT] DECREASE
# [PROP] BREEZE
# [KEY] FAN_DOWN
#
# [RESPONSE] Decreasing the air volume.
# ==================================================
# dry the room
#
# [DIRECT COMMAND]
# [ACT] DRY_ACT
# [OBJ] ENVIRONMENT
# [KEY] HUMIDITY_DOWN
#
# [RESPONSE] Drying the room.
# ==================================================
# decrease the humidity
#
# [DIRECT COMMAND]
# [ACT] DECREASE
# [PROP] HUMIDITY
# [KEY] HUMIDITY_DOWN
#
# [RESPONSE] Drying the room.
# ==================================================
# turn up the temperature by 3 degrees
#
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [PROP] TEMPERATURE
# [DIR] UP
# [VALUE] [{'CO': '3', 'UNIT': 'DEGREE', 'MODES': None}]
# [KEY] TEMP_UP
#
# [RESPONSE] Increasing the temperature to 3 DEGREE.
# ==================================================
# turn on the air-conditioner
#
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [OBJ] AC
# [DIR] ON
# [KEY] TURN_ON
#
# [RESPONSE] Started AC.
# ==================================================
# turn on the AC to 28 degrees
#
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [OBJ] AC
# [DIR] ON
# [VALUE] [{'CO': '28', 'UNIT': 'DEGREE', 'MODES': None}]
# [KEY] TURN_ON
#
# [RESPONSE] Starting ac at 28 DEGREE
# ==================================================
# turn the AC on to 25 degrees
#
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [OBJ] AC
# [DIR] ON
# [VALUE] [{'CO': '25', 'UNIT': 'DEGREE', 'MODES': None}]
# [KEY] TURN_ON
#
# [RESPONSE] Starting ac at 25 DEGREE
# ==================================================
# turn on the air-conditioner from 7 am to 4 p.m.
#
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [OBJ] AC
# [DIR] ON
# [VALUE] [{'CO': '7', 'UNIT': 'AM', 'MODES': None}, {'CO': '4', 'UNIT': 'PM', 'MODES': None}]
# [KEY] TURN_ON
#
# [RESPONSE] Starting ac from 7 AM to 4 PM.
# ==================================================
# turn on the air at 4 o'clock
#
# [WARNING] More than a single parse detected
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [PROP] BREEZE
# [DIR] ON
# [VALUE] [{'CO': '4', 'UNIT': 'O_CLOCK', 'MODES': None}]
# [KEY] SET_MODE
#
# [RESPONSE] Set mode to 4 O_CLOCK.
# ==================================================
# increase the temperature by 3 degrees
#
# [DIRECT COMMAND]
# [ACT] INCREASE
# [PROP] TEMPERATURE
# [VALUE] [{'CO': '3', 'UNIT': 'DEGREE', 'MODES': None}]
# [KEY] TEMP_UP
#
# [RESPONSE] Increasing the temperature to 3 DEGREE.
# ==================================================
# decrease the fan speed
#
# [DIRECT COMMAND]
# [ACT] DECREASE
# [PROP] VOLUME
# [OBJ] FAN
# [KEY] FAN_DOWN
#
# [RESPONSE] Decreasing the air volume.
# ==================================================
# cool down the room by 2 degrees
#
# [DIRECT COMMAND]
# [ACT] COOL_ACT
# [OBJ] ENVIRONMENT
# [DIR] DOWN
# [VALUE] [{'CO': '2', 'UNIT': 'DEGREE', 'MODES': None}]
# [KEY] TEMP_DOWN
#
# [RESPONSE] Decreasing the temperature to 2 DEGREE.
# ==================================================
# set the humidity to 23 %
#
# [DIRECT COMMAND]
# [ACT] SET
# [PROP] HUMIDITY
# [VALUE] [{'CO': '23', 'UNIT': 'PERCENT', 'MODES': None}]
# [KEY] SET_HUMIDITY
#
# [RESPONSE] Set humidity to 23 PERCENT.
# ==================================================
# set to fan mode
#
# [DIRECT COMMAND]
# [ACT] SET
# [VALUE] [{'CO': None, 'UNIT': None, 'MODES': 'FAN_MODE'}]
# [KEY] SET_MODE
#
# [RESPONSE] Set mode to FAN_MODE.
# ==================================================
# set the mode to cooling mode
#
# [DIRECT COMMAND]
# [ACT] SET
# [PROP] MODE
# [VALUE] [{'CO': None, 'UNIT': None, 'MODES': 'COOL_MODE'}]
# [KEY] SET_MODE
#
# [RESPONSE] Set mode to COOL_MODE.
# ==================================================
# turn on the air conditioner
#
# [DIRECT COMMAND]
# [ACT] TURN_ACT
# [OBJ] AC
# [DIR] ON
# [KEY] TURN_ON
#
# [RESPONSE] Started AC.
